# %%
import pandas as pd
import numpy as np

# %%
thousands=pd.read_csv('../data/merged_years/genres_csvs/2000s_cleanedup.csv', nrows=1000)

# %%
thousands
# Out:
#      Unnamed: 0                                       Title  \
# 0             0                      Oops!...I Did It Again
# 1             1                        All The Small Things
# 2             2                                     Breathe
# 3             3                                It's My Life
# 4             4                                 Bye Bye Bye
# ..          ...                                         ...
# 995          95  When Love Takes Over (feat. Kelly Rowland)
# 996          96                              I Love College
# 997          97                             Fallin' For You
# 998          98                             In For The Kill
# 999          99                         Throw It In The Bag
#
#                           Artist                 Artist_Replace  \
# 0                 Britney Spears                 Britney Spears
# 1                      blink-182                      blink-182
# ...

# %%
thousands=thousands.drop(columns=['Unnamed: 0','Artist','Genres','Sub_Genre'])

# %%
thousands=thousands.rename(columns={'Sub_Genre_Trimmed':'Sub_Genre', 'Genres_cleaned':'Genres','Artist_Replace':'Artist'})

# %%
thousands
# Out:
#                                           Title  \
# 0                        Oops!...I Did It Again
# 1                          All The Small Things
# 2                                       Breathe
# 3                                  It's My Life
# 4                                   Bye Bye Bye
# ..                                          ...
# 995  When Love Takes Over (feat. Kelly Rowland)
# 996                              I Love College
# 997                             Fallin' For You
# 998                             In For The Kill
# 999                         Throw It In The Bag
#
#                             Artist                          Album  Popularity  \
# 0                   Britney Spears        Oops!... I Did It Again          82
# 1                        blink-182             Enema Of The State          86
# 2                       Faith Hill                        Breathe          71
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
thousands['Sub_Genre'].value_counts()
# Out:
# pop                           164
# dance pop                      51
# gangster rap                   49
# hip hop                        43
# hip pop                        37
# dirty south rap                37
# modern rock                    32
# r&b                            30
# nu metal                       28
# europop                        24
# girl group                     21
# neo mellow                     18
# pop rock                       18
# neo soul                       17
# boy band                       17
# contemporary r&b               16
# east coast hip hop             14
# funk metal                     14
# canadian pop                   13
# dance rock                     12
# country                        12
# crunk                          11
# canadian rock                  11
# permanent wave                 11
# candy pop                      10
# miami hip hop                  10
# talent show                    10
# ...

# %%
def get_broad_category(sub_category):
    if sub_category == 'pop':
         return "Pop"
    if sub_category == 'dance pop':
         return "Pop"
    if sub_category == 'gangster rap':
         return "Hip-Hop"
    if sub_category == 'hip-hop':
         return "Hip-Hop"
    if sub_category == 'hip pop':
         return "Hip-Hop"
    if sub_category == 'dirty south rap':
         return "Hip-Hop"
    if sub_category == 'modern rock':
         return "Rock"
    if sub_category == 'r&b':
         return "R&B"
    if sub_category == 'nu metal':
         return "Heavy Metal"
    if sub_category == 'europop':
         return "Pop"
    if sub_category == 'girl group':
         return "Pop"
    if sub_category == 'neo mellow':
         return "Pop"
    if sub_category == 'pop rock':
         return "Pop"
    if sub_category == 'neo soul':
         return "R&B"
    if sub_category == 'nu metal':
         return "Metal"
    if sub_category == 'boy band':
         return "Pop"
    if sub_category == 'contemporary r&b':
         return "R&B"
    if sub_category == 'canadian pop':
         return "Pop"
    if sub_category == 'east coast hip hop':
         return "Hip-Hop"
    if sub_category == 'funk metal':
         return "Rock"
    if sub_category == 'canadian pop':
         return "Pop"
    if sub_category == 'dance rock':
         return "Rock"
    if sub_category == 'country':
         return "Country"
    if sub_category == 'crunk':
         return "Hip-Hop"
    if sub_category == 'canadian rock':
         return "Rock"
    if sub_category == 'permanent wave':
         return "Rock"
    if sub_category == 'candy pop':
         return "Pop"
    if sub_category == 'miami hip hop':
         return "Hip-Hop"
    if sub_category == 'talent show':
         return "Pop"
    if sub_category == 'piano rock':
         return "Rock"
    if sub_category == 'eurodance':
         return "EDM"
    if sub_category == 'rap':
         return "Hip-Hop"
    if sub_category == 'rock':
         return "Rock"
    if sub_category == 'hardcore hip hop':
         return "Hip-Hop"
    if sub_category == 'alternative rock':
         return "Rock"
    if sub_category == 'garage rock':
         return "Rock"
    if sub_category == 'pop rap':
         return "Hip-Hop"
    if sub_category == 'singer-songwriter':
         return "Pop"
    if sub_category == 'dancehall':
         return "Dance"
    if sub_category == 'british soul':
         return "R&B"
    if sub_category == 'southern hip hop':
         return "Hip-Hop"
    if sub_category == 'british soul':
         return "R&B"
    if sub_category == 'southern hip hop':
         return "Hip-Hop"
    if sub_category == 'pop punk':
         return "Punk Rock"
    if sub_category == 'filter house':
         return "Electronic"
    if sub_category == 'classic rock':
         return "Rock"
    if sub_category == 'latin pop':
         return "Pop"
    if sub_category == 'electro house':
         return "EDM"
    if sub_category == 'britpop':
         return "Pop"
    if sub_category == 'neon pop punk':
         return "Punk Rock"
    if sub_category == 'chicago bop':
         return "Hip-Hop"
    if sub_category == 'vocal house':
         return "EDM"
    if sub_category == 'australian pop':
         return "Pop"
    if sub_category == 'latin hip hop':
         return "Hip-Hop"
    if sub_category == 'golden age hip hop':
         return "Hio-Hop"
    if sub_category == 'new jack swing':
         return "R&B"
    if sub_category == 'uk garage':
         return "Hio-Hop"
    if sub_category == 'rap rock':
         return "Hip-Hop"
    if sub_category == 'alternative metal':
         return "Rock"
    if sub_category == 'dance':
         return "Dance"
    if sub_category == 'post-teen pop':
         return "Pop"
    if sub_category == 'new orleans rap':
         return "Hip-Hop"
    if sub_category == 'electropop':
         return "Pop"
    if sub_category == 'contemporary country':
         return "Country"
    if sub_category == 'uk pop':
         return "Pop"
    if sub_category == 'reggae fusion':
         return "Reggae"
    if sub_category == 'christian alternative rock':
         return "Rock"
    if sub_category == 'hip-hop':
         return "Hip-Hop"
    if sub_category == 'german techno':
         return "Electronic"
    if sub_category == 'edm':
         return "EDM"
    if sub_category == 'hard rock':
         return "Rock"
    if sub_category == 'edm':
         return "EDM"
    if sub_category == 'pixie':
         return "Punk Rock"
    if sub_category == 'lilith':
         return "Pop"
    if sub_category == 'swedish pop':
         return "Pop"
    if sub_category == 'chamber pop':
         return "Pop"
    if sub_category == 'canadian pop punk':
         return "Punk Rock"
    if sub_category == 'modern power pop':
         return "Pop"
    if sub_category == 'indie rock':
         return "Rock"
    if sub_category == 'italo dance':
         return "Dance"
    if sub_category == 'rockabilly':
         return "Rock"
    if sub_category == 'big beat':
         return "EDM"
    if sub_category == 'new wave pop':
         return "Pop"
    if sub_category == 'instrumental grime':
         return "Hip-Hop"
    if sub_category == 'middle earth':
         return "New Age"
    if sub_category == 'scottish singer-songwriter':
         return "Pop"
    if sub_category == 'onscious hip hop':
         return "Hip-Hop"
    if sub_category == 'pop soul':
         return "Soul"
    if sub_category == 'conscious hip hop':
         return "Hip-Hop"
    if sub_category == 'english indie rock':
         return "Pop"
    if sub_category == 'norwegian hip hop':
         return "Hip-Hop"
    if sub_category == 'metropopolis':
         return "Pop"
    if sub_category == 'filmi':
         return "Pop"
    if sub_category == 'country rap':
         return "Hip-Hop"
    if sub_category == 'australian electropop':
         return "Pop"
    if sub_category == 'ohio hip hop':
         return "Hip-Hop"
    if sub_category == 'wrestling':
         return "Rock"
    if sub_category == 'deep house':
         return "EDM"
    if sub_category == 'lds youth':
         return "Pop"
    if sub_category == 'harlem hip hop':
         return "Hip-Hop"
    if sub_category == 'breakbeat':
         return "EDM"
    if sub_category == 'scandipop':
         return "EDM"
    if sub_category == 'dance-punk':
         return "Rock"
    if sub_category == 'old school bassline':
         return "Rock"
    if sub_category == 'eau claire indie':
         return "Folk"
    if sub_category == 'toronto rap':
         return "Hip-Hop"
    if sub_category == 'quiet storm':
         return "R&B"
    if sub_category == 'idol':
         return "Pop"
    if sub_category == 'pop house':
         return "Dance"
    if sub_category == 'rap kreyol':
         return "Hip-Hop"
    if sub_category == 'indietronica':
         return "Electronic"
    if sub_category == 'swedish idol pop':
         return "Pop"
    if sub_category == 'dream pop':
         return "Pop"
    if sub_category == 'canadian singer-songwriter':
         return "Rock"
    if sub_category == 'atlanta bass':
         return "Hip-Hop"
    if sub_category == 'modern salsa':
         return "Pop"
    if sub_category == 'belgian pop':
         return "Hip-Hop"
    if sub_category == 'comedy rap':
         return "Hip-Hop"
    if sub_category == 'soul':
         return "Soul"
    if sub_category == 'urban contemporary':
         return "R&B"
    if sub_category == 'soft rock':
         return "Pop"
    if sub_category == 'emo':
         return "Punk Rock"
    if sub_category == 'trip hop':
         return "Hip-Hop"
    if sub_category == 'alternative r&b':
         return "R&B"
    if sub_category == 'post-grunge':
         return "Rock"
    if sub_category == 'british alternative rock':
         return "Rock"
    if sub_category == 'oktoberfest':
         return "Dance"
    if sub_category == 'mexican pop':
         return "Pop"
    if sub_category == 'gospel r&b':
         return "R&B"
    if sub_category == 'bahamian pop':
         return "Pop"
    if sub_category == 'british invasion':
         return "Pop"
    if sub_category == 'finnish edm':
         return "EDM"
    if sub_category == 'classic house':
         return "EDM"
    if sub_category == 'downtempo':
         return "EDM"
    if sub_category == 'jazz pop':
         return "Pop"
    if sub_category == 'trap queen':
         return "Hip-Hop"
    if sub_category == 'virginia hip hop':
         return "Hip-Hop"
    if sub_category == 'chicago hardcore':
         return "Punk Rock"
    if sub_category == 'hands up':
         return "EDM"
    if sub_category == 'uk dance':
         return "EDM"
    if sub_category == 'diva house':
         return "Hip-Hop"
    if sub_category == 'australian rock':
         return "Rock"
    if sub_category == 'vincy soca':
         return "Dance"
    if sub_category == 'reggaeton':
         return "Reggae"
    if sub_category == 'australian talent show':
         return "Pop"
    if sub_category == 'new romantic':
         return "Alternative"
    if sub_category == 'danish pop':
         return "Pop"
    if sub_category == 'classic bhangra':
         return "Pop"
    if sub_category == 'canadian metal':
         return "Rock"
    if sub_category == 'blues rock':
         return "Rock"
    if sub_category == 'bubblegum dance':
         return "Pop"
    if sub_category == 'indie pop rap':
         return "Hip-Hop"
    if sub_category == 'hip hop':
         return "Hip-Hop"
    else:
         return "Other"

# %%
thousands['Main Genre'] = thousands['Sub_Genre'].apply(get_broad_category)

# %%
thousands.loc[thousands['Main Genre']=='Other']
# Out:
# Empty DataFrame
# Columns: [Title, Artist, Album, Popularity, Play Count, Track URL, Acousticness, Danceability, Loudness, Valence, Energy, Liveness, Tempo, Explicit, Instrumentalness, Duration (ms), Genres, Sub_Genre, Release Year, Main Genre]
# Index: []

# %%
thousands.loc[thousands['Artist']=="Destiny's Child", 'Main Genre']='R&B'
thousands.loc[thousands['Artist']=="Plain White T's", 'Main Genre']='Rock'
thousands.loc[thousands['Artist']=='Uncle Kracker', 'Main Genre']='Country'
thousands.loc[thousands['Artist']=='The Calling', 'Main Genre']='Rock'
thousands.loc[thousands['Artist']=='Corinne Bailey Rae', 'Main Genre']='Pop'
thousands.loc[thousands['Artist']=='Amy Winehouse', 'Main Genre']='R&B'
thousands.loc[thousands['Artist']=='112', 'Main Genre']='R&B'
thousands.loc[thousands['Artist']=='Sugar Ray', 'Main Genre']='Rock'
thousands.loc[thousands['Artist']=='Scissor Sister','Main Genre']='Pop'
thousands.loc[thousands['Artist']=='The Offspring', 'Main Genre']='Punk Rock'
thousands.loc[thousands['Artist']=='Gym Class Heroes','Main Genre']='Rock'
thousands.loc[thousands['Artist']=='Mario Winans','Main Genre']='R&B'

# %%
thousands=thousands[['Title','Artist','Album','Popularity','Play Count','Track URL','Acousticness','Danceability','Loudness','Valence','Energy','Liveness','Tempo','Explicit','Instrumentalness','Duration (ms)','Genres','Sub_Genre','Main Genre','Release Year']]

# %%
thousands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             1000 non-null   object
#  1   Artist            1000 non-null   object
#  2   Album             1000 non-null   object
#  3   Popularity        1000 non-null   int64
#  4   Play Count        1000 non-null   float64
#  5   Track URL         1000 non-null   object
#  6   Acousticness      999 non-null    float64
#  7   Danceability      999 non-null    float64
#  8   Loudness          999 non-null    float64
#  9   Valence           999 non-null    float64
#  10  Energy            999 non-null    float64
#  11  Liveness          999 non-null    float64
#  12  Tempo             999 non-null    float64
#  13  Explicit          1000 non-null   bool
#  14  Instrumentalness  999 non-null    float64
#  15  Duration (ms)     1000 non-null   int64
# ...

# %%
null_mask=thousands.isnull()
rows_with_null = thousands[null_mask.any(axis=1)]

# %%
rows_with_null
# Out:
#            Title               Artist      Album  Popularity  Play Count  \
# 453  These Words  Natasha Bedingfield  Unwritten          68   1106676.2
#
#                                              Track URL  Acousticness  \
# 453  https://open.spotify.com/track/6MFQeWtk7kxWGyd...           NaN
#
#      Danceability  Loudness  Valence  Energy  Liveness  Tempo  Explicit  \
# 453           NaN       NaN      NaN     NaN       NaN    NaN     False
#
#      Instrumentalness  Duration (ms)                         Genres Sub_Genre  \
# 453               NaN         216360  dance pop, pop, post-teen pop       pop
#
#     Main Genre  Release Year
# 453        Pop          2004

# %%
row_number = 453
thousands= thousands.drop(thousands.index[row_number])

# %%
thousands.loc[thousands['Artist']=="Natasha Bedingfield"]
# Out:
#                      Title               Artist                  Album  \
# 616              Unwritten  Natasha Bedingfield              Unwritten
# 843  Pocketful of Sunshine  Natasha Bedingfield  Pocketful Of Sunshine
#
#      Popularity  Play Count  \
# 616          81        14.0
# 843          74        13.0
#
#                                              Track URL  Acousticness  \
# 616  https://open.spotify.com/track/3U5JVgI2x4rDyHG...       0.00584
# 843  https://open.spotify.com/track/1uigwk5hNV84zRd...       0.19100
#
#      Danceability  Loudness  Valence  Energy  Liveness    Tempo  Explicit  \
# 616         0.706    -6.333    0.629    0.80    0.0822  100.011     False
# 843         0.721    -3.896    0.655    0.88    0.0769  110.021     False
#
#      Instrumentalness  Duration (ms)                         Genres Sub_Genre  \
# 616               0.0         259333  dance pop, pop, post-teen pop       pop
# ...

# %%
thousands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             999 non-null    object
#  1   Artist            999 non-null    object
#  2   Album             999 non-null    object
#  3   Popularity        999 non-null    int64
#  4   Play Count        999 non-null    float64
#  5   Track URL         999 non-null    object
#  6   Acousticness      999 non-null    float64
#  7   Danceability      999 non-null    float64
#  8   Loudness          999 non-null    float64
#  9   Valence           999 non-null    float64
#  10  Energy            999 non-null    float64
#  11  Liveness          999 non-null    float64
#  12  Tempo             999 non-null    float64
#  13  Explicit          999 non-null    bool
#  14  Instrumentalness  999 non-null    float64
#  15  Duration (ms)     999 non-null    int64
# ...

# %%
thousands.to_csv('../data/merged_years/full_cleans/twothousands.csv')

# %%
thousands['Main Genre'].value_counts()
# Out:
# Pop            386
# Hip-Hop        260
# Rock           139
# R&B             87
# Heavy Metal     28
# EDM             28
# Country         17
# Punk Rock       17
# Dance           15
# Electronic       8
# Hio-Hop          6
# Reggae           3
# Soul             2
# New Age          1
# Alternative      1
# Folk             1
# Name: Main Genre, dtype: int64
