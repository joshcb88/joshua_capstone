# %%
import pandas as pd
import numpy as np

# %%
theteens=pd.read_csv('../data/merged_years/genres_csvs/2010s_cleanedup.csv',nrows=1030)

# %%
theteens

# %%
theteens=theteens.drop(columns=['Unnamed: 0','Artist','Genres','Sub_Genre'])

# %%
theteens=theteens.rename(columns={'Sub_Genre_Trimmed':'Sub_Genre', 'Genres_cleaned':'Genres','Artist_Replace':'Artist'})

# %%
theteens

# %%
pd.set_option('display.max_rows', None)

# %%
theteens['Sub_Genre'].value_counts()

# %%
def get_broad_category(sub_category):
    if sub_category == 'pop':
         return "Pop"
    if sub_category == 'edm':
         return "EDM"
    if sub_category == 'pop rap':
         return "Hip-Hop"
    if sub_category == 'hip hop':
         return "Hip-Hop"
    if sub_category == 'dance pop':
         return "Pop"
    if sub_category == 'rap':
         return "Hip-Hop"
    if sub_category == 'canadian pop':
         return "Pop"
    if sub_category == 'modern rock':
         return "Rock"
    if sub_category == 'miami hip hop':
         return "Hip-Hop"
    if sub_category == 'r&b':
         return "R&B"
    if sub_category == 'post-teen pop':
         return "Pop"
    if sub_category == 'uk pop':
         return "Pop"
    if sub_category == 'metropopolis':
         return "Pop"
    if sub_category == 'singer-songwriter pop':
         return "Pop"
    if sub_category == 'country':
         return "Country"
    if sub_category == 'melodic rap':
         return "Hip-Hop"
    if sub_category == 'neo mellow':
         return "Rock"
    if sub_category == 'electropop':
         return "Hip-Hop"
    if sub_category == 'electropop':
         return "Pop"
    if sub_category == 'latin pop':
         return "Pop"
    if sub_category == 'gangster rap':
         return "Hip-Hop"
    if sub_category == 'viral pop':
         return "Pop"
    if sub_category == 'electro house':
         return "EDM"
    if sub_category == 'australian pop':
         return "Pop"
    if sub_category == 'electronic trap':
         return "EDM"
    if sub_category == 'indie pop rap':
         return "Hip-Hop"
    if sub_category == 'scandipop':
         return "Pop"
    if sub_category == 'house':
         return "EDM"
    if sub_category == 'contemporary r&b':
         return "R&B"
    if sub_category == 'modern alternative rock':
         return "Rock"
    if sub_category == 'neo soul':
         return "Hip-Hop"
    if sub_category == 'neo-singer-songwriter':
         return "Folk"
    if sub_category == 'new orleans rap':
         return "Hip-Hop"
    if sub_category == 'indietronica':
         return "Indie"
    if sub_category == 'viral trap':
         return "Hip-Hop"
    if sub_category == 'detroit hip hop':
         return "Hip-Hop"
    if sub_category == 'pop r&b':
         return "R&B"
    if sub_category == 'oakland hip hop':
         return "Hip-Hop"
    if sub_category == 'talent show':
         return "Pop"
    if sub_category == 'Seattle hip hop':
         return "Hip-Hop"
    if sub_category == 'pittsburgh rap':
         return "Hip-Hop"
    if sub_category == 'puerto rican pop':
         return "Pop"
    if sub_category == 'brostep':
         return "EDM"
    if sub_category == 'reggae fusion':
         return "Reggae"
    if sub_category == 'trap latino':
         return "Hip-Hop"
    if sub_category == 'pixie':
         return "Punk Rock"
    if sub_category == 'mississippi hip hop':
         return "Hip-Hop"
    if sub_category == 'indie pop':
         return "Pop"
    if sub_category == 'latin viral pop':
         return "Pop"
    if sub_category == 'pop soul':
         return "Pop"
    if sub_category == 'philly rap':
         return "Hip-Hop"
    if sub_category == 'hip hop':
         return "Hip-Hop"
    if sub_category == 'reggaeton flow':
         return "Reggaeton"
    if sub_category == 'pop punk':
         return "Pop"
    if sub_category == 'pop rock':
         return "Rock"
    if sub_category == 'movie tunes':
         return "Soundtrack"
    if sub_category == 'trap':
         return "Hip-Hop"
    if sub_category == 'emo rap':
         return "Hip-Hop"
    if sub_category == 'conscious hip hop':
         return "Hip-Hop"
    if sub_category == 'pop edm':
         return "Pop"
    if sub_category == 'drum and bass':
         return "EDM"
    if sub_category == 'filter house':
         return "Electronic"
    if sub_category == 'idol':
         return "Pop"
    if sub_category == 'idol':
         return "Pop"
    if sub_category == 'canadian trap':
         return "Hip-Hop"
    if sub_category == 'canadian trap':
         return "Hip-Hop"
    if sub_category == 'romanian pop':
         return "Hip-Hop"
    if sub_category == 'singer-songwriter':
         return "Pop"
    if sub_category == 'folk-pop':
         return "Pop"
    if sub_category == 'australian electropop':
         return "EDM"
    if sub_category == 'dirty south rap':
         return "Hip-Hop"
    if sub_category == 'etherpop':
         return "Pop"
    if sub_category == 'etherpop':
         return "Pop"
    if sub_category == 'europop':
         return "Pop"
    if sub_category == 'la indie':
         return "Pop"
    if sub_category == 'florida rap':
         return "Hip-Hop"
    if sub_category == 'lgbtq+ hip hop':
         return "Hip-Hop"
    if sub_category == 'uk hip hop':
         return "Hip-Hop"
    if sub_category == 'candy pop':
         return "Punk Rock"
    if sub_category == 'minnesota hip hop':
         return "Hip-Hop"
    if sub_category == 'swedish tropical house':
         return "EDM"
    if sub_category == 'australian hip hop':
         return "Hip-Hop"
    if sub_category == 'norwegian pop':
         return "Pop"
    if sub_category == 'grime':
         return "EDM"
    if sub_category == 'uk house':
         return "EDM"
    if sub_category == 'neon pop punk':
         return "Pop"
    if sub_category == 'australian trap':
         return "Hip-Hop"
    if sub_category == 'dancehall':
         return "Reggae"
    if sub_category == 'pov: indie':
         return "Hip-Hop"
    if sub_category == 'k-pop boy group':
         return "K-Pop"
    if sub_category == 'pluggnb':
         return "R&B"
    if sub_category == 'electro trash':
         return "Electronic"
    if sub_category == 'show tunes':
         return "Soundtrack"
    if sub_category == 'israeli pop':
         return "Pop"
    if sub_category == 'g-house':
         return "EDM"
    if sub_category == 'atl trap':
         return "Hip-Hop"
    if sub_category == 'portland hip hop':
         return "Hip-Hop"
    if sub_category == 'hawaiian hip hop':
         return "Hip-Hop"
    if sub_category == 'rap latina':
         return "Hip-Hop"
    if sub_category == 'canadian contemporary r&b':
         return "R&B"
    if sub_category == 'plugg':
         return "Hip-Hop"
    if sub_category == 'indie rock':
         return "Rock"
    if sub_category == 'acoustic pop':
         return "Pop"
    if sub_category == 'reggaeton colombiano':
         return "Reggaeton"
    if sub_category == 'deep house':
         return "EDM"
    if sub_category == 'pop nacional':
         return "Pop"
    if sub_category == 'girl group':
         return "Pop"
    if sub_category == 'israeli rock':
         return "Rock"
    if sub_category == 'permanent wave':
         return "Muse"
    if sub_category == 'complextro':
         return "Rock"
    if sub_category == 'permanent wave':
         return "EDM"
    if sub_category == 'hip house':
         return "Hip-Hop"
    if sub_category == 'korean old school hip hop':
         return "Hip-Hop"
    if sub_category == 'nu metal':
         return "Rock"
    if sub_category == 'stomp and holler':
         return "Folk"
    if sub_category == 'australian house':
         return "EDM"
    if sub_category == 'eau claire indie':
         return "Folk"
    if sub_category == 'french synthpop':
         return "Pop"
    if sub_category == 'contemporary country':
         return "Country"
    if sub_category == 'funk metal':
         return "Rock"
    if sub_category == 'canadian rock':
         return "Rock"
    if sub_category == 'sertanejo universitario':
         return "Pop"
    if sub_category == 'canadian electropop':
         return "Electronic"
    if sub_category == 'chill pop':
         return "Pop"
    if sub_category == 'comic':
         return "Comedy"
    if sub_category == 'uk contemporary r&b':
         return "R&B"
    if sub_category == 'teen pop':
         return "Pop"
    if sub_category == 'afrobeats':
         return "Pop"
    if sub_category == 'piano  rock':
         return "Pop"
    if sub_category == 'indie poptimism':
         return "Pop"
    if sub_category == 'lilith':
         return "Pop"
    if sub_category == 'french rock':
         return "Rock"
    if sub_category == 'icelandic rock':
         return "Rock"
    if sub_category == 'atl hip hop':
         return "Hip-Hop"
    if sub_category == 'virgin islands reggae':
         return "Reggae"
    if sub_category == 'german dance':
         return "Dance"
    if sub_category == 'modern blues rock':
         return "Rock"
    if sub_category == 'new french touch':
         return "Electronic"
    if sub_category == 'k-pop girl group':
         return "K-Pop"
    if sub_category == 'pop dance':
         return "Pop"
    if sub_category == 'hip pop':
         return "Hip-Hop"
    if sub_category == 'uk dance':
         return "Dance"
    if sub_category == 'piano rock':
         return "Dance"
    if sub_category == 'reggaeton':
         return "Reggateon"
    if sub_category == 'seattle hip hop':
         return "Hip-Hop"
    if sub_category == 'trap argentino':
         return "Hip-Hop"
    if sub_category == 'glam rock':
         return "Rock"
    if sub_category == 'trap queen':
         return "Hip-Hop"
    if sub_category == 'north carolina hip hop':
         return "Hip-Hop"
    if sub_category == 'country rap':
         return "Hip-Hop"
    else:
        return "Other"

# %%
theteens['Main Genre'] = theteens['Sub_Genre'].apply(get_broad_category)

# %%
theteens.loc[theteens['Main Genre']=='Other']

# %%
theteens.loc[theteens['Artist']=='Gym Class HEroes','Main Genre']='Rock'
theteens.loc[theteens['Artist']=='James Morrison','Main Genre']='Pop'
theteens.loc[theteens['Artist']=='Sheppard','Main Genre']='Pop'

# %%
theteens=theteens[['Title','Artist','Album','Popularity','Play Count','Track URL','Acousticness','Danceability','Loudness','Valence','Energy','Liveness','Tempo','Explicit','Instrumentalness','Duration (ms)','Genres','Sub_Genre','Main Genre','Release Year']]

# %%
theteens.info()

# %%
theteens.to_csv('../data/merged_years/full_cleans/thousandteen.csv')
